# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
raw_data = pd.read_csv('reallifedata.csv')

# %%
raw_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year             Model
# 0             yes  1991               320
# ...

# %%
data = raw_data.drop(['Model'],axis=1)

# %%
data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    4173.000000  4345.000000  4195.000000  4345.000000
# mean    19418.746935   161.237284     2.790734  2006.550058
# std     25584.242620   105.705797     5.066437     6.719097
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    86.000000     1.800000  2003.000000
# 50%     11500.000000   155.000000     2.200000  2008.000000
# 75%     21700.000000   230.000000     3.000000  2012.000000
# max    300000.000000   980.000000    99.990000  2016.000000

# %%
data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# # Dealing with null values

# %%
data.isnull()
# Out:
#       Brand  Price   Body  Mileage  EngineV  Engine Type  Registration   Year
# 0     False  False  False    False    False        False         False  False
# 1     False  False  False    False    False        False         False  False
# 2     False  False  False    False    False        False         False  False
# 3     False  False  False    False    False        False         False  False
# 4     False  False  False    False    False        False         False  False
# ...     ...    ...    ...      ...      ...          ...           ...    ...
# 4340  False  False  False    False    False        False         False  False
# 4341  False  False  False    False    False        False         False  False
# 4342  False  False  False    False    False        False         False  False
# 4343  False  False  False    False     True        False         False  False
# 4344  False  False  False    False    False        False         False  False
#
# [4345 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv = data.dropna(axis=0)

# %%
data_no_mv
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data_no_mv.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    4025.000000  4025.000000  4025.000000  4025.000000
# mean    19552.308065   163.572174     2.764586  2006.379627
# std     25815.734988   103.394703     4.935941     6.695595
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    90.000000     1.800000  2003.000000
# 50%     11500.000000   158.000000     2.200000  2007.000000
# 75%     21900.000000   230.000000     3.000000  2012.000000
# max    300000.000000   980.000000    99.990000  2016.000000

# %%
data_no_mv.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %%
data_no_mv.isnull()
# Out:
#       Brand  Price   Body  Mileage  EngineV  Engine Type  Registration   Year
# 0     False  False  False    False    False        False         False  False
# 1     False  False  False    False    False        False         False  False
# 2     False  False  False    False    False        False         False  False
# 3     False  False  False    False    False        False         False  False
# 4     False  False  False    False    False        False         False  False
# ...     ...    ...    ...      ...      ...          ...           ...    ...
# 4339  False  False  False    False    False        False         False  False
# 4340  False  False  False    False    False        False         False  False
# 4341  False  False  False    False    False        False         False  False
# 4342  False  False  False    False    False        False         False  False
# 4344  False  False  False    False    False        False         False  False
#
# [4025 rows x 8 columns]

# %%
data_no_mv.isnull().sum()
# Out:
# Brand           0
# Price           0
# Body            0
# Mileage         0
# EngineV         0
# Engine Type     0
# Registration    0
# Year            0
# dtype: int64

# %% [markdown]
# # Explore the data

# %%
sns.distplot(data_no_mv['Price'])
plt.show()
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\2498179368.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Price'])

# %%
q = data_no_mv['Price'].quantile(0.99)

# %%
data_1 = data_no_mv[data_no_mv['Price']<q]

# %%
data_1.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_1['Price'])
plt.show()
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\300526289.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Price'])

# %%
sns.distplot(data_no_mv["Mileage"])
plt.show()
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\3561653625.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv["Mileage"])

# %%
q = data_no_mv['Mileage'].quantile(0.99)

# %%
data_2 = data_1[data_1['Mileage']<q]

# %%
data_2.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3943    3943.000000   3943  3943.000000  3943.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           867            NaN   1510          NaN          NaN
# mean           NaN   17936.780614    NaN   161.414659     2.747497
# std            NaN   19009.750360    NaN    95.940408     4.981033
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    7000.000000    NaN    92.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21417.500000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000    99.990000
#
#        Engine Type Registration         Year
# count         3943         3943  3943.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_2['Mileage'])
plt.show()
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\253818997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Mileage'])

# %%
sns.distplot(data_no_mv['EngineV'])
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\823394628.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
data_no_mv
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data_no_mv.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    4025.000000  4025.000000  4025.000000  4025.000000
# mean    19552.308065   163.572174     2.764586  2006.379627
# std     25815.734988   103.394703     4.935941     6.695595
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    90.000000     1.800000  2003.000000
# 50%     11500.000000   158.000000     2.200000  2007.000000
# 75%     21900.000000   230.000000     3.000000  2012.000000
# max    300000.000000   980.000000    99.990000  2016.000000

# %%
data_3 = data_2[data_2['EngineV']<6.5]

# %%
data_3.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    3920.000000  3920.000000  3920.000000  3920.000000
# mean    17991.352031   161.209949     2.443304  2006.409184
# std     19043.203478    95.980959     0.946242     6.593734
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      7000.000000    92.000000     1.800000  2003.000000
# 50%     11500.000000   158.000000     2.200000  2008.000000
# 75%     21500.000000   229.000000     3.000000  2012.000000
# max    129222.000000   433.000000     6.300000  2016.000000

# %%
sns.distplot(data_3['EngineV'])
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\1902427236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
sns.distplot(data_no_mv['Year'])
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\534082538.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
q = data_3['Year'].quantile(0.01)

# %%
data_4 = data_3[data_3['Year']>q]

# %%
sns.distplot(data_4['Year'])
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\2748958191.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_4['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
data_4
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4338     Volkswagen   11500.0        van      163      2.5      Diesel
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data_cleaned = data_4.reset_index(drop=True)

# %%
data_cleaned
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3861     Volkswagen   11500.0        van      163      2.5      Diesel
# 3862         Toyota   17900.0      sedan       35      1.6      Petrol
# 3863  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3864            BMW    6500.0      sedan        1      3.5      Petrol
# 3865     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %% [markdown]
# # Linearity

# %%
f,(ax1,ax2,ax3) = plt.subplots(1,3,sharey=True,figsize=(15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Year and Price')

ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])
ax2.set_title('EngineV and Price')

ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title('Mileage and Price')
plt.show()

# %%
sns.distplot(data_cleaned['Price'])
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\462586877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_cleaned['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
log_price = np.log(data_cleaned['Price'])

# %%
sns.distplot(log_price)
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\1286630314.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data_cleaned['log_price'] = log_price

# %%
data_cleaned
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3861     Volkswagen   11500.0        van      163      2.5      Diesel
# 3862         Toyota   17900.0      sedan       35      1.6      Petrol
# 3863  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3864            BMW    6500.0      sedan        1      3.5      Petrol
# 3865     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# ...

# %%
f,(ax1,ax2,ax3) = plt.subplots(1,3,sharey=True,figsize=(15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title('Year and log Price')

ax2.scatter(data_cleaned['EngineV'],data_cleaned['log_price'])
ax2.set_title('EnginV and log Price')

ax3.scatter(data_cleaned['Mileage'],data_cleaned['log_price'])
ax3.set_title('Mileage and log Price')

plt.show()

# %%
data_cleaned = data_cleaned.drop(['Price'],axis=1)

# %%
data_cleaned
# Out:
#               Brand       Body  Mileage  EngineV Engine Type Registration  \
# 0               BMW      sedan      277      2.0      Petrol          yes
# 1     Mercedes-Benz        van      427      2.9      Diesel          yes
# 2     Mercedes-Benz      sedan      358      5.0         Gas          yes
# 3              Audi  crossover      240      4.2      Petrol          yes
# 4            Toyota  crossover      120      2.0      Petrol          yes
# ...             ...        ...      ...      ...         ...          ...
# 3861     Volkswagen        van      163      2.5      Diesel          yes
# 3862         Toyota      sedan       35      1.6      Petrol          yes
# 3863  Mercedes-Benz      sedan        9      3.0      Diesel          yes
# 3864            BMW      sedan        1      3.5      Petrol          yes
# 3865     Volkswagen        van      124      2.0      Diesel          yes
#
#       Year  log_price
# 0     1991   8.342840
# 1     1999   8.974618
# ...

# %% [markdown]
# # Multicolinearty

# %%
data_cleaned.columns.values
# Out:
# array(['Brand', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'log_price'], dtype=object)

# %%
variables= data_cleaned[['Mileage','Year','EngineV']]

# %%
variables
# Out:
#       Mileage  Year  EngineV
# 0         277  1991      2.0
# 1         427  1999      2.9
# 2         358  2003      5.0
# 3         240  2007      4.2
# 4         120  2011      2.0
# ...       ...   ...      ...
# 3861      163  2008      2.5
# 3862       35  2014      1.6
# 3863        9  2014      3.0
# 3864        1  1999      3.5
# 3865      124  2013      2.0
#
# [3866 rows x 3 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
variables.shape[1]
# Out:
# 3

# %%
vif['VIF'] = [variance_inflation_factor(variables.values,i)for i in range(variables.shape[1])]

# %%
vif
# Out:
#          VIF
# 0   3.794319
# 1  10.360888
# 2   7.660317

# %%
vif['Features Name'] = variables.columns

# %%
vif
# Out:
#          VIF Features Name
# 0   3.794319       Mileage
# 1  10.360888          Year
# 2   7.660317       EngineV

# %%
data_no_multicolinearty = data_cleaned.drop(['Year'],axis=1)

# %%
data_no_multicolinearty
# Out:
#               Brand       Body  Mileage  EngineV Engine Type Registration  \
# 0               BMW      sedan      277      2.0      Petrol          yes
# 1     Mercedes-Benz        van      427      2.9      Diesel          yes
# 2     Mercedes-Benz      sedan      358      5.0         Gas          yes
# 3              Audi  crossover      240      4.2      Petrol          yes
# 4            Toyota  crossover      120      2.0      Petrol          yes
# ...             ...        ...      ...      ...         ...          ...
# 3861     Volkswagen        van      163      2.5      Diesel          yes
# 3862         Toyota      sedan       35      1.6      Petrol          yes
# 3863  Mercedes-Benz      sedan        9      3.0      Diesel          yes
# 3864            BMW      sedan        1      3.5      Petrol          yes
# 3865     Volkswagen        van      124      2.0      Diesel          yes
#
#       log_price
# 0      8.342840
# 1      8.974618
# 2      9.495519
# ...

# %% [markdown]
# # Categoricle Variables

# %%
data_no_multicolinearty.describe(include='all')
# Out:
#              Brand   Body      Mileage      EngineV Engine Type Registration  \
# count         3866   3866  3866.000000  3866.000000        3866         3866
# unique           7      6          NaN          NaN           4            2
# top     Volkswagen  sedan          NaN          NaN      Diesel          yes
# freq           848   1466          NaN          NaN        1807         3504
# mean           NaN    NaN   160.471547     2.450246         NaN          NaN
# std            NaN    NaN    95.543697     0.949413         NaN          NaN
# min            NaN    NaN     0.000000     0.600000         NaN          NaN
# 25%            NaN    NaN    91.000000     1.800000         NaN          NaN
# 50%            NaN    NaN   157.000000     2.200000         NaN          NaN
# 75%            NaN    NaN   225.000000     3.000000         NaN          NaN
# max            NaN    NaN   433.000000     6.300000         NaN          NaN
#
#           log_price
# count   3866.000000
# ...

# %%
data_with_dummies = pd.get_dummies(data_no_multicolinearty,drop_first=True)

# %%
data_with_dummies
# Out:
#       Mileage  EngineV  log_price  Brand_BMW  Brand_Mercedes-Benz  \
# 0         277      2.0   8.342840       True                False
# 1         427      2.9   8.974618      False                 True
# 2         358      5.0   9.495519      False                 True
# 3         240      4.2  10.043249      False                False
# 4         120      2.0   9.814656      False                False
# ...       ...      ...        ...        ...                  ...
# 3861      163      2.5   9.350102      False                False
# 3862       35      1.6   9.792556      False                False
# 3863        9      3.0  11.736069      False                 True
# 3864        1      3.5   8.779557       True                False
# 3865      124      2.0   9.510445      False                False
#
#       Brand_Mitsubishi  Brand_Renault  Brand_Toyota  Brand_Volkswagen  \
# 0                False          False         False             False
# ...

# %%
targets = data_with_dummies['log_price'] #y = dep

# %%
targets
# Out:
# 0        8.342840
# 1        8.974618
# 2        9.495519
# 3       10.043249
# 4        9.814656
#           ...
# 3861     9.350102
# 3862     9.792556
# 3863    11.736069
# 3864     8.779557
# 3865     9.510445
# Name: log_price, Length: 3866, dtype: float64

# %%
inputs = data_with_dummies.drop(['log_price'],axis=1)

# %%
inputs
# Out:
#       Mileage  EngineV  Brand_BMW  Brand_Mercedes-Benz  Brand_Mitsubishi  \
# 0         277      2.0       True                False             False
# 1         427      2.9      False                 True             False
# 2         358      5.0      False                 True             False
# 3         240      4.2      False                False             False
# 4         120      2.0      False                False             False
# ...       ...      ...        ...                  ...               ...
# 3861      163      2.5      False                False             False
# 3862       35      1.6      False                False             False
# 3863        9      3.0      False                 True             False
# 3864        1      3.5       True                False             False
# 3865      124      2.0      False                False             False
#
#       Brand_Renault  Brand_Toyota  Brand_Volkswagen  Body_hatch  Body_other  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
input_scaled = scaler.transform(inputs)

# %%
input_scaled
# Out:
# array([[ 1.21979294, -0.47429745,  2.27936676, ..., -0.16211373,
#          1.33315372,  0.32141951],
#        [ 2.7899583 ,  0.47377973, -0.43871834, ..., -0.16211373,
#         -0.75010104,  0.32141951],
#        [ 2.06768224,  2.68595982, -0.43871834, ..., -0.16211373,
#         -0.75010104,  0.32141951],
#        ...,
#        [-1.58556918,  0.57912164, -0.43871834, ..., -0.16211373,
#         -0.75010104,  0.32141951],
#        [-1.66931133,  1.10583119,  2.27936676, ..., -0.16211373,
#          1.33315372,  0.32141951],
#        [-0.38177573, -0.47429745, -0.43871834, ..., -0.16211373,
#         -0.75010104,  0.32141951]])

# %%
df = pd.DataFrame(input_scaled)

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.219793 -0.474297  2.279367 -0.492228 -0.291095 -0.354684 -0.384529
# 1     2.789958  0.473780 -0.438718  2.031581 -0.291095 -0.354684 -0.384529
# 2     2.067682  2.685960 -0.438718  2.031581 -0.291095 -0.354684 -0.384529
# 3     0.832485  1.843225 -0.438718 -0.492228 -0.291095 -0.354684 -0.384529
# 4    -0.423647 -0.474297 -0.438718 -0.492228 -0.291095 -0.354684  2.600587
# ...        ...       ...       ...       ...       ...       ...       ...
# 3861  0.026467  0.052412 -0.438718 -0.492228 -0.291095 -0.354684 -0.384529
# 3862 -1.313407 -0.895665 -0.438718 -0.492228 -0.291095 -0.354684  2.600587
# 3863 -1.585569  0.579122 -0.438718  2.031581 -0.291095 -0.354684 -0.384529
# 3864 -1.669311  1.105831  2.279367 -0.492228 -0.291095 -0.354684 -0.384529
# 3865 -0.381776 -0.474297 -0.438718 -0.492228 -0.291095 -0.354684 -0.384529
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(input_scaled,targets,test_size=0.2,random_state=365)

# %%
X_train.shape
# Out:
# (3092, 17)

# %%
X_test.shape
# Out:
# (774, 17)

# %%
y_train.shape
# Out:
# (3092,)

# %%
y_test.shape
# Out:
# (774,)

# %% [markdown]
# # Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
yhat = reg.predict(X_train)

# %%
plt.scatter(y_train,yhat)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %%
sns.distplot(y_train-yhat)
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_6612\642810972.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train-yhat)
# <Axes: xlabel='log_price', ylabel='Density'>

# %%
reg.score(X_train,y_train)
# Out:
# 0.7415645182486199

# %%
reg.intercept_
# Out:
# 9.413280072375791

# %%
reg.coef_
# Out:
# array([-0.44838367,  0.21092609,  0.01217236,  0.01091936, -0.13381235,
#        -0.18243069, -0.05551416, -0.08742151, -0.15127967, -0.10115164,
#        -0.19711525, -0.1281566 , -0.16265036, -0.12418232, -0.03326347,
#        -0.14940858,  0.31944559])

# %%
reg_summary = pd.DataFrame(inputs.columns.values,columns=['Features'])

# %%
reg_summary
# Out:
#                Features
# 0               Mileage
# 1               EngineV
# 2             Brand_BMW
# 3   Brand_Mercedes-Benz
# 4      Brand_Mitsubishi
# 5         Brand_Renault
# 6          Brand_Toyota
# 7      Brand_Volkswagen
# 8            Body_hatch
# 9            Body_other
# 10           Body_sedan
# 11           Body_vagon
# 12             Body_van
# 13      Engine Type_Gas
# 14    Engine Type_Other
# 15   Engine Type_Petrol
# 16     Registration_yes

# %%
reg_summary['Slope'] = reg.coef_

# %%
reg_summary
# Out:
#                Features     Slope
# 0               Mileage -0.477134
# 1               EngineV  0.252793
# 2             Brand_BMW  0.026598
# 3   Brand_Mercedes-Benz  0.036006
# 4      Brand_Mitsubishi -0.127270
# 5         Brand_Renault -0.166703
# 6          Brand_Toyota -0.048485
# 7      Brand_Volkswagen -0.071804
# 8            Body_hatch -0.140250
# 9            Body_other -0.096221
# 10           Body_sedan -0.191630
# 11           Body_vagon -0.108906
# 12             Body_van -0.156996
# 13      Engine Type_Gas -0.122483
# 14    Engine Type_Other -0.030676
# 15   Engine Type_Petrol -0.141366
# 16     Registration_yes  0.310713

# %% [markdown]
# # Testing

# %%
yhat_test = reg.predict(X_test)

# %%
yhat_test
# Out:
# array([ 7.82289483,  8.91684609,  9.51020896,  8.93235854,  9.71128643,
#         9.08047022, 10.51700779,  8.54267652,  9.86889703,  9.27765503,
#         8.81348826,  8.58222325, 10.69784668,  9.13596839,  8.77939378,
#         9.1046247 ,  9.31473802, 10.28200309,  9.25355168,  9.44282377,
#         9.80428639,  9.34446337,  9.54095023, 10.77112899,  8.15811767,
#         7.18162737,  8.7312942 ,  9.94246621,  9.86686483,  8.64390869,
#         9.56776021,  9.46399705, 10.18716423,  9.92972846, 10.18096656,
#         9.79271859,  9.07496353, 11.05899259,  9.07510999,  9.62452377,
#         8.37881652,  9.02160694,  9.93311995,  9.43657181,  8.580645  ,
#        10.44368108, 11.15063317,  8.30181086,  9.57627511,  8.17719587,
#         8.25944036, 10.64668369, 10.11795804,  9.45695632, 10.38546929,
#         9.07654389,  8.88330441,  8.73315709, 10.36074374,  8.87153947,
#         9.77083019,  9.37468154,  8.64259605,  9.75653348,  9.56262613,
# ...

# %%
y_test
# Out:
# 1259    7.495542
# 167     9.287301
# 1616    9.609116
# 1826    9.305651
# 921     9.740910
#           ...
# 3064    7.575585
# 3894    9.968104
# 211     9.510445
# 3700    8.732305
# 1284    9.495519
# Name: log_price, Length: 782, dtype: float64

# %%
plt.scatter(y_test,yhat_test)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()
